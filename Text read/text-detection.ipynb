# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../input/english-handwritten-line-dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ../input/english-handwritten-line-dataset/lines.txt
# ../input/english-handwritten-line-dataset/self_lines/selfMade_188.png
# ../input/english-handwritten-line-dataset/self_lines/selfMade_292.png
# ../input/english-handwritten-line-dataset/self_lines/selfMade_2.png
# ../input/english-handwritten-line-dataset/self_lines/selfMade_332.png
# ../input/english-handwritten-line-dataset/self_lines/selfMade_290.png
# ../input/english-handwritten-line-dataset/self_lines/selfMade_151.png
# ../input/english-handwritten-line-dataset/self_lines/selfMade_208.png
# ../input/english-handwritten-line-dataset/self_lines/selfMade_380.png
# ../input/english-handwritten-line-dataset/self_lines/selfMade_364.png
# ../input/english-handwritten-line-dataset/self_lines/selfMade_11.png
# ../input/english-handwritten-line-dataset/self_lines/selfMade_34.png
# ../input/english-handwritten-line-dataset/self_lines/selfMade_253.png
# ../input/english-handwritten-line-dataset/self_lines/selfMade_170.png
# ...

# %%
import pytesseract
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('../input/english-handwritten-line-dataset/self_lines/selfMade_126.png')
plt.figure(figsize=(10,10))
plt.imshow(img, cmap ='gray')

# %%
img=cv2.imread('../input/english-handwritten-line-dataset/self_lines/selfMade_126.png')
text = pytesseract.image_to_string(img)
print(text)
# Out:
# been around for many years, but they were not

# %%
img=mpimg.imread('../input/iam-handwritten-forms-dataset/data/029/a02-053.png')
plt.figure(figsize=(10,10))
plt.imshow(img, cmap ='gray')

# %%
img=cv2.imread('../input/iam-handwritten-forms-dataset/data/029/a02-053.png')
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Sentence Database A02-053
#
# It has been left, however, to Mr. Goka, Ghana’s Finance Minister, to do the honours
# as host, in which capacity he held a reception tonight in Accra’s Ambassador Hotel.
# POLICE, on direct orders from the Cabinet, are openly intimidating members of Earl
# Russell’s nuclear-disarming Committee of 100, the Committee claimed yesterday. It
# said pressure was being put on members and associates all over the country.
#
# If has been lef, however, to He. Goka, Ghana's Finance
# lurusies, to do tho honouss as best, in wich capacity
# he held a recephon torught in Accfa's Ambassador
# Holl. POLICE, on direct orders from the Cabinet, are
# openly inhmudating membess of torl Qussell's mucleays-
# csarmung Commute of joo, tne Committee claumed
# yesterday H odd pmcsswe was bang put on
#
# members and assouaks all over the Coury.
#
# Name:

# %%
img=mpimg.imread('../input/tdection/td.jpeg')
plt.figure(figsize=(10,10))
plt.imshow(img, cmap ='gray')

# %%
img=cv2.imread('../input/tdection/td.jpeg')
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Its Emma. | tried to call you but
# signal bad. | been taken to
# hospital after having a fall this
# morning. If possible can you do
# me a quick favour and text me x

# %%
img=mpimg.imread('../input/hhhhhhhhhhhhhhhhh/WhatsApp Image 2022-11-07 at 3.17.38 PM.jpeg')
plt.figure(figsize=(10,10))
plt.imshow(img, cmap ='gray')

# %%
img=cv2.imread('../input/hhhhhhhhhhhhhhhhh/WhatsApp Image 2022-11-07 at 3.17.38 PM.jpeg')
text = pytesseract.image_to_string(img)
print(text)
